# %%
W1 = '/artic/t-kaneko/work/val_bit_serial/numpy/pro/pollux01/210108/210108_1950_resnet18_cifar100_ser_8_h1_201214_1941.npy'
W2 = '/artic/t-kaneko/work/val_bit_serial/numpy/pro/pollux01/210108/210108_1951_resnet18_cifar100_ser_8_h2_201214_2014.npy'
W3 = '/artic/t-kaneko/work/val_bit_serial/numpy/pro/pollux01/210108/210108_1951_resnet18_cifar100_ser_8_h3_201214_2046.npy'
W4 = '/artic/t-kaneko/work/val_bit_serial/numpy/pro/pollux01/210108/210108_1951_resnet18_cifar100_ser_8_h4_201214_2057.npy'
W5 = '/artic/t-kaneko/work/val_bit_serial/numpy/pro/pollux01/210108/210108_1951_resnet18_cifar100_ser_8_h5_201214_2108.npy'
W6 = '/artic/t-kaneko/work/val_bit_serial/numpy/pro/pollux01/210108/210108_1951_resnet18_cifar100_ser_8_h6_201214_2119.npy'
W7 = '/artic/t-kaneko/work/val_bit_serial/numpy/pro/pollux01/210108/210108_1952_resnet18_cifar100_ser_8_h7_201214_2131.npy'
W8 = '/artic/t-kaneko/work/val_bit_serial/numpy/pro/pollux01/210108/210108_1952_resnet18_cifar100_ser_8_h8_201214_2142.npy'

# %%
E1 = '/artic/t-kaneko/work/val_bit_serial/numpy/data/pollux01/201217/201217_1527_resnet18_cifar100_ser_8_h1_201214_1941.npy'
E2 = '/artic/t-kaneko/work/val_bit_serial/numpy/data/pollux01/201217/201217_1528_resnet18_cifar100_ser_8_h2_201214_2014.npy'
E3 = '/artic/t-kaneko/work/val_bit_serial/numpy/data/pollux01/201217/201217_1529_resnet18_cifar100_ser_8_h3_201214_2046.npy'
E4 = '/artic/t-kaneko/work/val_bit_serial/numpy/data/pollux01/201217/201217_1529_resnet18_cifar100_ser_8_h4_201214_2057.npy'
E5 = '/artic/t-kaneko/work/val_bit_serial/numpy/data/pollux01/201217/201217_1530_resnet18_cifar100_ser_8_h5_201214_2108.npy'
E6 = '/artic/t-kaneko/work/val_bit_serial/numpy/data/pollux01/201217/201217_1530_resnet18_cifar100_ser_8_h6_201214_2119.npy'
E7 = '/artic/t-kaneko/work/val_bit_serial/numpy/data/pollux01/201217/201217_1531_resnet18_cifar100_ser_8_h7_201214_2131.npy'
E8 = '/artic/t-kaneko/work/val_bit_serial/numpy/data/pollux01/201217/201217_1532_resnet18_cifar100_ser_8_h8_201214_2142.npy'

# %%
L1 = '/artic/t-kaneko/work/val_bit_serial/numpy/label/pollux01/210116/210116_0720_resnet18_cifar100_ser_8_h1_201214_1941.npy'
L2 = '/artic/t-kaneko/work/val_bit_serial/numpy/label/pollux01/210116/210116_0720_resnet18_cifar100_ser_8_h2_201214_2014.npy'
L3 = '/artic/t-kaneko/work/val_bit_serial/numpy/label/pollux01/210116/210116_0720_resnet18_cifar100_ser_8_h3_201214_2046.npy'
L4 = '/artic/t-kaneko/work/val_bit_serial/numpy/label/pollux01/210116/210116_0721_resnet18_cifar100_ser_8_h4_201214_2057.npy'
L5 = '/artic/t-kaneko/work/val_bit_serial/numpy/label/pollux01/210116/210116_0721_resnet18_cifar100_ser_8_h5_201214_2108.npy'
L6 = '/artic/t-kaneko/work/val_bit_serial/numpy/label/pollux01/210116/210116_0721_resnet18_cifar100_ser_8_h6_201214_2119.npy'
L7 = '/artic/t-kaneko/work/val_bit_serial/numpy/label/pollux01/210116/210116_0721_resnet18_cifar100_ser_8_h7_201214_2131.npy'
L8 = '/artic/t-kaneko/work/val_bit_serial/numpy/label/pollux01/210116/210116_0721_resnet18_cifar100_ser_8_h8_201214_2142.npy'

# %%
import numpy as np
import matplotlib.pyplot as plt
pro_list = []
sorted_list = []
for i in range(8):
    exec('pro = np.load(W%s, allow_pickle=True)' % (i + 1))
    pro_list.append(pro)
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
orig_list = []
sorted_list = []
for i in range(8):
    exec('orig = np.load(E%s)' % (i + 1))
    orig_list.append(orig)

# %%
label_list = []
for i in range(8):
    exec('lab = np.load(L%s, allow_pickle=True)' % (i + 1))
    label_list.append(lab)

# %%
import torch
def entropy(a):
    e = (torch.log2(a) * (-a)).sum()
    return e.to('cpu').detach().numpy().copy()

# %%
value_list = [[[], [], [], [],[],[],[],[]],[[], [], [], [],[],[],[],[]],[[], [], [], [],[],[],[],[]],[[], [], [], [],[],[],[],[]],[[], [], [], [],[],[],[],[]],[[], [], [], [],[],[],[],[]],[[], [], [], [],[],[],[],[]],[[], [], [], [],[],[],[],[]],[[], [], [], [],[],[],[],[]],[[], [], [], [],[],[],[],[]],[[], [], [], [],[],[],[],[]],[[], [], [], [],[],[],[],[]],[[], [], [], [],[],[],[],[]],[[], [], [], [],[],[],[],[]],[[], [], [], [],[],[],[],[]],[[], [], [], [],[],[],[],[]]]
labels_list =  [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# value_list = np.zeros((16,8))
for j in range(10000):
    for a in range(2):
        for b in range(2):
            for c in range(2):
                for d in range(2):
                    if (orig_list[0][1][j] == a) and (orig_list[1][1][j] == b) and (orig_list[2][1][j] == c) and (orig_list[3][1][j] == d):
#                         print(int('%s%s%s%s' % (a,b,c,d), 2))
                        value_list[int('%s%s%s%s' % (a,b,c,d), 2)][0].append(pro_list[0][j])
                        value_list[int('%s%s%s%s' % (a,b,c,d), 2)][1].append(pro_list[1][j])
                        value_list[int('%s%s%s%s' % (a,b,c,d), 2)][2].append(pro_list[2][j])
                        value_list[int('%s%s%s%s' % (a,b,c,d), 2)][3].append(pro_list[3][j])
                        value_list[int('%s%s%s%s' % (a,b,c,d), 2)][4].append(pro_list[4][j])
                        value_list[int('%s%s%s%s' % (a,b,c,d), 2)][5].append(pro_list[5][j])
                        value_list[int('%s%s%s%s' % (a,b,c,d), 2)][6].append(pro_list[6][j])
                        value_list[int('%s%s%s%s' % (a,b,c,d), 2)][7].append(pro_list[7][j])
                        labels_list[int('%s%s%s%s' % (a,b,c,d), 2)].append(label_list[0][j])

# %%
n = 5
x_ax = np.arange(100)
for i in range(0, len(value_list[0][3]), int(len(value_list[0][3])/n)):
    fig = plt.figure(figsize=(15.0, 5.0))
    ax1 = fig.add_subplot(121, xlabel='class', ylabel='probability', title='1×2×3×4×')
    ax2 = fig.add_subplot(122, xlabel='bit', ylabel='entropy', title='1×2×3×4×')
    e = []
    for j in range(4):
        ax1.plot(x_ax, value_list[0][j][i].to('cpu').detach().numpy().copy(), label='{}bit'.format(j+1))
        e.append(entropy(value_list[0][j][i]))
    ax2.plot([1,2,3,4], e)
    ax2.set_xlim([1,4])
    ax2.set_ylim([0,7])
    ax1.legend()

# %%
for i in range(0, len(value_list[1][3]), int(len(value_list[1][3])/n)):
    fig = plt.figure(figsize=(15.0, 5.0))
    ax1 = fig.add_subplot(121, xlabel='class', ylabel='probability', title='1×2×3×4○')
    ax2 = fig.add_subplot(122, xlabel='bit', ylabel='entropy', title='1×2×3×4○')
    e = []
    for j in range(4):
        ax1.plot(x_ax, value_list[1][j][i].to('cpu').detach().numpy().copy(), label='{}bit'.format(j+1))
        e.append(entropy(value_list[1][j][i]))
    ax2.plot([1,2,3,4], e)
    ax2.set_xlim([1,4])
    ax2.set_ylim([0,7])
    ax1.legend()

# %%
for i in range(0, len(value_list[3][3]), int(len(value_list[3][3])/n)):
    fig = plt.figure(figsize=(15.0, 5.0))
    ax1 = fig.add_subplot(121, xlabel='class', ylabel='probability', title='1×2×3○4○')
    ax2 = fig.add_subplot(122, xlabel='bit', ylabel='entropy', title='1×2×3○4○')
    e = []
    for j in range(4):
        ax1.plot(x_ax, value_list[3][j][i].to('cpu').detach().numpy().copy(), label='{}bit'.format(j+1))
        e.append(entropy(value_list[3][j][i]))
    ax2.plot([1,2,3,4], e)
    ax2.set_xlim([1,4])
    ax2.set_ylim([0,7])
    ax1.legend()

# %%
for i in range(0, len(value_list[7][3]), int(len(value_list[7][3])/n)):
    fig = plt.figure(figsize=(15.0, 5.0))
    ax1 = fig.add_subplot(121, xlabel='class', ylabel='probability', title='1×2○3○4○')
    ax2 = fig.add_subplot(122, xlabel='bit', ylabel='entropy', title='1×2○3○4○')
    e = []
    for j in range(4):
        ax1.plot(x_ax, value_list[7][j][i].to('cpu').detach().numpy().copy(), label='{}bit'.format(j+1))
        e.append(entropy(value_list[7][j][i]))
    ax2.plot([1,2,3,4], e)
    ax2.set_xlim([1,4])
    ax2.set_ylim([0,7])
    ax1.legend()

# %%
for i in range(0, len(value_list[15][3]), int(len(value_list[15][3])/n)):
    fig = plt.figure(figsize=(15.0, 5.0))
    ax1 = fig.add_subplot(121, xlabel='class', ylabel='probability', title='1○2○3○4○')
    ax2 = fig.add_subplot(122, xlabel='bit', ylabel='entropy', title='1○2○3○4○')
    e = []
    for j in range(4):
        ax1.plot(x_ax, value_list[15][j][i].to('cpu').detach().numpy().copy(), label='{}bit'.format(j+1))
        e.append(entropy(value_list[15][j][i]))
    ax2.plot([1,2,3,4], e)
    ax2.set_xlim([1,4])
    ax2.set_ylim([0,7])
    ax1.legend()

# %%
def detect_title(k):
    if k == 0:
        title = '1×2×3×4×'
    elif k == 1:
        title = '1×2×3×4○'
    elif k == 2:
        title = '1×2×3○4×'
    elif k == 3:
        title = '1×2×3○4○'
    elif k == 4:
        title = '1×2○3×4×'
    elif k == 5:
        title = '1×2○3×4○'
    elif k == 6:
        title = '1×2○3○4×'
    elif k == 7:
        title = '1×2○3○4○'
    elif k == 8:
        title = '1○2×3×4×'
    elif k == 9:
        title = '1○2×3×4○'
    elif k == 10:
        title = '1○2×3○4×'
    elif k == 11:
        title = '1○2×3○4○'
    elif k == 12:
        title = '1○2○3×4×'
    elif k == 13:
        title = '1○2○3×4○'
    elif k == 14:
        title = '1○2○3○4×'
    elif k == 15:
        title = '1○2○3○4○'
    return title

# %%
import random
# k=0:1×2×3×4×  k=1:1×2×3×4○ k=3:1×2×3○4○ k=7:1×2○3○4○ k=15:1○2○3○4○
klist = [3] 
n = 1
ent_list = [[0,1],[0,2],[0,3],[1,2],[1,3],[2,3],[0,1,2,3]]
save = 0
x_ax = np.arange(100)
random.seed(1)

for k in klist:
    title = detect_title(k)
    for _ in range(n):
        i = random.randint(0, len(value_list[k][3]))
        for elist in ent_list:
            fig = plt.figure(figsize=(15.0, 5.0))
            ax1 = fig.add_subplot(121, xlabel='class', ylabel='probability', title=title)
            ax2 = fig.add_subplot(122, xlabel='bit', ylabel='entropy', title=title)
            e = []
            for j in elist:
                ax1.plot(x_ax, value_list[k][j][i].to('cpu').detach().numpy().copy(), label='{}bit'.format(j+1))
                e.append(entropy(value_list[k][j][i]))
            ax1.vlines(x=labels_list[k][i],ymin=0,ymax=1)
            ax2.plot([el+1 for el in elist], e)
            ax2.set_xlim([1,4])
            ax2.set_ylim([0,7])
            ax1.legend()
            if save:
                if len(elist) == 2:
                    fig.savefig('fig/k{}/pro-ent_k{}_i{}_{}{}bit.png'.format(k, k, i, elist[0]+1, elist[-1]+1))
                else:
                    fig.savefig('fig/k{}/pro-ent_k{}_i{}_{}-{}bit.png'.format(k, k, i, elist[0]+1, elist[-1]+1))

# %%
k = 3
i = 107
elist = [0,1,2,3]
e = []
save = 1
fig1, ax1 = plt.subplots(2,2,figsize=(10,8))
fig2 = plt.figure()
# ax1 = fig1.add_subplot(111, xlabel='class', ylabel='probability')
ax2 = fig2.add_subplot(111, xlabel='bit', ylabel='entropy')
color = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']
for j in elist:
    tmp = value_list[k][j][i].to('cpu').detach().numpy().copy()
    ax1[int((j-j%2)/2)][j%2].plot(x_ax, tmp, label='{}bit'.format(j+1), color=color[j])
    ax1[int((j-j%2)/2)][j%2].set_ylim([0,0.8])
    ax1[int((j-j%2)/2)][j%2].legend()
    ax1[int((j-j%2)/2)][j%2].set_xlabel('class')
    ax1[int((j-j%2)/2)][j%2].set_ylabel('probability')
    ax1[int((j-j%2)/2)][j%2].plot(95,tmp[95],marker='o', markersize=5, color='black')
    e.append(entropy(value_list[k][j][i]))
ax2.plot([el+1 for el in elist], e)
ax2.set_ylim([0,6])
ax2.set_xticks([1.0,2.0,3.0,4.0]) 
ax2.set_xticklabels(["1","2","3","4","5"])
print(labels_list[k][i])
if save:
    fig1.savefig('fig/k3_i107_1-4pro.pdf')
    fig2.savefig('fig/k3_i107_1-4ent.pdf')
# Out:
# tensor(95, device='cuda:0')

# %%
co1 = 0
co2 = 0
co3 = 0
co4 = 0
bit =4 
for k in range(len(value_list)): 
        for i in range(len(value_list[k][0])): 
            key = np.zeros(bit, dtype=int) 
            for b in range(bit):
                key[b] = value_list[k][b][i].argmax()
            if len(set(key)) ==1:
                co1 +=1
            elif len(set(key)) ==2:
                co2 += 1
            elif len(set(key)) ==3:
                co3 += 1
            elif len(set(key)) ==4:
                co4 += 1

# %%
print(co1,co2,co3,co4)
# Out:
# 6103 2875 875 147

# %%
bit = 4
# th_ee = 5.5
th_ee_list = np.arange(4,6,0.1)
doubt_list = np.zeros((len(th_ee_list),16),dtype=int)
for t, th_ee in enumerate(th_ee_list):
    for k in range(len(value_list)): 
        for i in range(len(value_list[k][0])): 
            key = np.zeros(bit, dtype=int) 
            for b in range(bit):
                key[b] = value_list[k][b][i].argmax() 
            if len(set(key)) >= 3:
                if (entropy(value_list[k][3][i])>th_ee) and (entropy(value_list[k][2][i])>th_ee) and (entropy(value_list[k][1][i])>th_ee) and (entropy(value_list[k][0][i])>th_ee):
                    doubt_list[t][k] += 1

# %%
doubt_rate = []
save = 1
for i in range(len(doubt_list)):
    print(doubt_list[i][0],th_ee_list[i])
    print(doubt_list[i][0]/sum(doubt_list[i]))
    doubt_rate.append(doubt_list[i][0]/sum(doubt_list[i]))
plt.plot(th_ee_list,doubt_rate)
plt.xlim(4.0, 4.9)
plt.ylim(0.4, 0.6)
plt.xlabel('e (< entropy)')
plt.ylabel('1×2×3×4× ratio')
plt.plot(4.6,0.5517241379310345, marker='o')
if save:
    plt.savefig('fig/argmax3.pdf')
#     for j in range(16):
#         print('{}:{}, {}'.format(detect_title(j), doubt_list[i][j], doubt_list[i][j]/len(value_list[j][0])))
# print(doubt_list[0]/sum(doubt_list))
# Out:
# 221 4.0
# 0.5351089588377724
# 203 4.1
# 0.5356200527704486
# 187 4.199999999999999
# 0.5327635327635327
# 166 4.299999999999999
# 0.5337620578778135
# 146 4.399999999999999
# 0.5347985347985348
# 128 4.499999999999998
# 0.5446808510638298
# 112 4.599999999999998
# 0.5517241379310345
# 85 4.6999999999999975
# 0.5345911949685535
# 61 4.799999999999997
# 0.4959349593495935
# 48 4.899999999999997
# 0.5217391304347826
# 38 4.9999999999999964
# 0.5066666666666667
# 33 5.099999999999996
# 0.5892857142857143
# 20 5.199999999999996
# 0.5882352941176471
# 11 5.299999999999995
# 0.55
# 7 5.399999999999995
# 0.5384615384615384
# 6 5.499999999999995
# 0.8571428571428571
# 3 5.599999999999994
# 0.75
# 1 5.699999999999994
# 0.5
# 1 5.799999999999994
# 1.0
# 0 5.899999999999993
# nan
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in long_scalars
#   """
# ...

# %%
ent_list=[[[],[],[],[]],[[],[],[],[]],[[],[],[],[]],[[],[],[],[]],[[],[],[],[]],[[],[],[],[]],[[],[],[],[]],[[],[],[],[]],[[],[],[],[]],[[],[],[],[]],[[],[],[],[]],[[],[],[],[]],[[],[],[],[]],[[],[],[],[]],[[],[],[],[]],[[],[],[],[]]]
for k in range(len(value_list)): #0~15 patern
    for j in range(len(value_list[k])): #0~4 (+1)bit
        for i in range(len(value_list[k][j])): #0~
            ent_list[k][j].append(entropy(value_list[k][j][i]))

# %%
np.shape(value_list[0][3][0])
len(labels_list[0])

# %%
#　デバッグ
for k in range(len(value_list)): 
    for j in range(len(value_list[k])): 
        for i in range(len(value_list[k][j])):
            if ent_list[k][j][i] != entropy(value_list[k][j][i]):
                print('!!!error!!!')

# %%
bit = 0
po_list = np.zeros(16, dtype=int)
ne_list = np.zeros(16, dtype=int)
for k in range(len(value_list)):
    for i in range(len(value_list[k][0])):
        if ent_list[k][bit][i] < ent_list[k][3][i]:
            po_list[k] += 1
        elif ent_list[k][bit][i] > ent_list[k][3][i]:
            ne_list[k] += 1

# %%
print(po_list)
print(ne_list)

# %%
bit = 0
eq_list = np.zeros(16, dtype=int)
ne_list = np.zeros(16, dtype=int)
for k in range(len(value_list)):
    for i in range(len(value_list[k][0])):
        if value_list[k][bit][i].argmax() == value_list[k][3][i].argmax():
            eq_list[k] += 1
        elif value_list[k][bit][i].argmax() != value_list[k][3][i].argmax():
            ne_list[k] += 1

# %%
for i in range(len(eq_list)):
    print('{}:{}, {}'.format(detect_title(i), eq_list[i], ne_list[i]))

# %%
th_p = 1.0
p_count = np.zeros(16, dtype=int)
n_count = np.zeros(16, dtype=int)
for k in range(len(value_list)): 
    for i in range(len(value_list[k][bit])):
        if value_list[k][bit][i].argmax() != value_list[k][3][i].argmax():
            if (ent_list[k][bit][i] * th_p) < ent_list[k][3][i]:
                p_count[k] += 1
            elif (ent_list[k][bit][i] * th_p) > ent_list[k][3][i]:
                n_count[k] += 1

# %%
for i in range(len(p_count)):
    print('{}:{}, {}'.format(detect_title(i), p_count[i], n_count[i]))

# %%
th_e1 = 2
th_pp = 1.0
bit = 0
p_count = np.zeros(16, dtype=int)
for k in range(len(value_list)): 
    for i in range(len(value_list[k][bit])):
        if value_list[k][bit][i].argmax() == value_list[k][3][i].argmax():
            if th_e1 < ent_list[k][bit][i]:
                 if (ent_list[k][bit][i] * th_pp) < ent_list[k][3][i]:
                    p_count[k] += 1
print(p_count[0]/sum(p_count))
for i in range(len(p_count)):
    print('{}:{}'.format(detect_title(i), p_count[i]))
